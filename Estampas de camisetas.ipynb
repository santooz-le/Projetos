# %%
import pyautogui as py
import time as t

# %%
py.alert("O código vai começar")
py.PAUSE = 0.38
py.hotkey("alt", "tab")
# Nomes a serem usados
def get_name_list():
    names = ["1r", "2r", "3r", "4r", "6r", "7r", "8r","10r", "11r", "12r"]
    return names    

nl = get_name_list()
def apaga():
    t.sleep(0.38)
    py.click(1177,649, button = "right")
    t.sleep(0.38)
    py.click(1016, 85)
    t.sleep(2)

# Ajustar a parte de cima da imagem
def camisa():
    t.sleep(0.12)
    # Pressionar e segurar Shift
    py.keyDown("shift")
    py.moveTo(469,381)
    py.mouseDown()
    py.moveTo(413,272)
    py.mouseUp()
    py.keyUp("shift")

    # Ajustar a parte inferior
    py.keyDown("shift")
    py.moveTo(573,453)
    py.mouseDown()
    py.moveTo(624,420)
    py.mouseUp()
    py.keyUp("shift")

    # Salvar a imagem
    py.press("enter")
    py.hotkey("ctrl", "s")
    t.sleep(10)
    py.hotkey("ctrl", "tab")
    t.sleep(1)
    py.hotkey("ctrl", "shift", "alt", "s")
    t.sleep(10)
    py.doubleClick(888,612)
    py.write("1024")
    py.press("enter")
    py.click(886, 717)
    t.sleep(3)

camisa()
t.sleep(2.5)
py.write(nl[0])
t.sleep(0.5)
py.click(764, 440)
t.sleep(0.5)
py.hotkey("ctrl", "tab")
t.sleep(0.5)

# Pegar próximo arquivo
py.keyDown("alt")
py.press("tab")
py.press("tab")
py.keyUp("alt")
t.sleep(0.3)
py.moveTo(1165,432)
py.mouseDown()
py.moveTo(495, 398)
py.mouseUp()
t.sleep(0.5)
camisa()
t.sleep(2.5)
py.write(nl[1])
py.click(764, 440)
t.sleep(0.5)
py.hotkey("ctrl", "tab")
t.sleep(0.5)

# Pegar próximo arquivo
py.keyDown("alt")
py.press("tab")
py.keyUp("alt")
t.sleep(0.5)
py.moveTo(1278,432)
py.mouseDown()
py.moveTo(495, 398)
py.mouseUp()
t.sleep(0.2)
camisa()
t.sleep(2.5)
py.write(nl[2])
py.click(764, 440)
t.sleep(0.5)
py.hotkey("ctrl", "tab")
t.sleep(0.5)

# Pegar próximo arquivo
py.keyDown("alt")
py.press("tab")
py.keyUp("alt")
t.sleep(0.5)
py.moveTo(1050,504)
py.mouseDown()
py.moveTo(495, 398)
py.mouseUp()
t.sleep(0.2)
camisa()
t.sleep(2.5)
py.write(nl[3])
py.click(764, 440)
t.sleep(0.5)
py.hotkey("ctrl", "tab")
t.sleep(0.5)

# Pegar próximo arquivo
py.keyDown("alt")
py.press("tab")
py.keyUp("alt")
t.sleep(0.5)
py.moveTo(1282,510)
py.mouseDown()
py.moveTo(495, 398)
py.mouseUp()
t.sleep(0.2)
camisa()
t.sleep(2.5)
py.write(nl[4])
py.click(764, 440)
t.sleep(0.5)
py.hotkey("ctrl", "tab")
t.sleep(0.5)

# Pegar próximo arquivo
py.keyDown("alt")
py.press("tab")
py.keyUp("alt")
t.sleep(0.5)
py.moveTo(1046,602)
py.mouseDown()
py.moveTo(495, 398)
py.mouseUp()
t.sleep(0.2)
camisa()
t.sleep(2.5)
py.write(nl[5])
py.click(764, 440)
t.sleep(0.5)
py.hotkey("ctrl", "tab")
t.sleep(0.5)

# Pegar próximo arquivo
py.keyDown("alt")
py.press("tab")
py.keyUp("alt")
t.sleep(0.5)
py.moveTo(1165,606)
py.mouseDown()
py.moveTo(495, 398)
py.mouseUp()
t.sleep(0.2)
t.sleep(0.12)
# Pressionar e segurar Shift
py.keyDown("shift")
py.moveTo(473,379)
py.mouseDown()
py.moveTo(414,274)
py.mouseUp()
py.keyUp("shift")

# Ajustar a parte inferior
py.keyDown("shift")
py.moveTo(575,458)
py.mouseDown()
py.moveTo(628,418)
py.mouseUp()
py.keyUp("shift")
t.sleep(1)

#centralizar imagem:
py.keyDown("shift")
py.moveTo(521,347)
py.mouseDown()
py.moveTo(517,359)
py.mouseUp()
py.keyUp("shift")

# Salvar a imagem
py.press("enter")
py.hotkey("ctrl", "s")
t.sleep(10)
py.hotkey("ctrl", "tab")
t.sleep(1)
py.hotkey("ctrl", "shift", "alt", "s")
t.sleep(10)
py.doubleClick(888,612)
py.write("1024")
py.press("enter")
py.click(886, 717)
t.sleep(2)
t.sleep(2.5)
py.write(nl[6])
py.click(764, 440)
t.sleep(0.5)
py.hotkey("ctrl", "tab")
t.sleep(0.5)

#apagar os anteriores
t.sleep(0.38)
py.click(1175,606, button = "right")
t.sleep(0.38)
py.click(1016, 85)
t.sleep(2)
for x in range(6):
    apaga()

# Pegar próximo arquivo
py.keyDown("alt")
py.press("tab")
py.keyUp("alt")
t.sleep(0.5)
py.moveTo(1049,695)
py.mouseDown()
py.moveTo(495, 398)
py.mouseUp()
t.sleep(0.2)
t.sleep(1)
# Pressionar e segurar Shift
py.keyDown("shift")
py.moveTo(470,380)
py.mouseDown()
py.moveTo(416,296)
py.mouseUp()
py.keyUp("shift")

# Ajustar a parte inferior
py.keyDown("shift")
py.moveTo(574,453)
py.mouseDown()
py.moveTo(624,436)
py.mouseUp()
py.keyUp("shift")

#centrelaziar esse tipo:
py.keyDown("shift")
py.moveTo(517,370)
py.mouseDown()
py.moveTo(516,304)
py.mouseUp()
py.keyUp("shift")
t.sleep(1)
# Salvar a imagem
py.press("enter")
t.sleep(0.3)
py.click(1081,647)
t.sleep(1)
py.hotkey("ctrl", "s")
t.sleep(10)
py.click(1083,610)
py.hotkey("ctrl", "tab")
t.sleep(1)
py.hotkey("ctrl", "shift", "alt", "s")
t.sleep(10)
py.doubleClick(888,612)
py.write("1024")
py.press("enter")
py.click(886, 717)
t.sleep(2)
t.sleep(2.5)
py.write(nl[7])
py.click(764, 440)
t.sleep(0.5)
py.hotkey("ctrl", "tab")
t.sleep(0.5)

t.sleep(0.38)
py.click(1193,651, button = "right")
t.sleep(0.38)
py.click(1016, 85)
t.sleep(2)

# Pegar próximo arquivo
py.keyDown("alt")
py.press("tab")
py.keyUp("alt")
t.sleep(0.5)
py.moveTo(1160,693)
py.mouseDown()
py.moveTo(495, 398)
py.mouseUp()
t.sleep(0.2)
t.sleep(0.12)

# Pressionar e segurar Shift
py.keyDown("shift")
py.moveTo(470,380)
py.mouseDown()
py.moveTo(416,296)
py.mouseUp()
py.keyUp("shift")

# Ajustar a parte inferior
py.keyDown("shift")
py.moveTo(574,453)
py.mouseDown()
py.moveTo(624,436)
py.mouseUp()
py.keyUp("shift")

#centrelaziar esse tipo:
py.keyDown("shift")
py.moveTo(517,370)
py.mouseDown()
py.moveTo(516,304)
py.mouseUp()
py.keyUp("shift")
t.sleep(1)

# Salvar a imagem
py.press("enter")
py.hotkey("ctrl", "s")
t.sleep(10)
py.hotkey("ctrl", "tab")
t.sleep(1)
py.hotkey("ctrl", "shift", "alt", "s")
t.sleep(10)
py.doubleClick(888,612)
py.write("1024")
py.press("enter")
py.click(886, 717)
t.sleep(2)
t.sleep(2.5)
py.write(nl[8])
py.click(764, 440)
t.sleep(0.5)
py.hotkey("ctrl", "tab")
t.sleep(1.5)

py.click(1083,610)
py.click(1081,647)

# Pegar próximo arquivo
t.sleep(1)
py.keyDown("alt")
py.press("tab")
py.keyUp("alt")
t.sleep(0.5)
py.moveTo(1273,695)
py.mouseDown()
py.moveTo(495, 398)
py.mouseUp()
t.sleep(0.3)
# Pressionar e segurar Shift
py.keyDown("shift")
py.moveTo(471,382)
py.mouseDown()
py.moveTo(420,242)
py.mouseUp()
py.keyUp("shift")

# Ajustar a parte inferior
py.keyDown("shift")
py.moveTo(574,456)
py.mouseDown()
py.moveTo(623,386)
py.mouseUp()
py.keyUp("shift")

#diminuir e centrelaziar esse tipo:
py.keyDown("shift")
py.moveTo(416,237)
py.mouseDown()
py.moveTo(426,278)
py.mouseUp()
py.keyUp("shift")
py.moveTo(524,330)
py.mouseDown()
py.moveTo(519,328)
py.mouseUp()

# Salvar a imagem
py.press("enter")
py.hotkey("ctrl", "s")
t.sleep(10)
py.hotkey("ctrl", "tab")
t.sleep(1)
py.hotkey("ctrl", "shift", "alt", "s")
t.sleep(10)
py.doubleClick(888,612)
py.write("1024")
py.press("enter")
py.click(886, 717)
t.sleep(2)
t.sleep(2.5)
py.write(nl[9])
py.click(764, 440)
t.sleep(0.5)
py.hotkey("ctrl", "tab")
t.sleep(0.5)

py.alert("Acabou")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 py.alert("O código vai começar")
#       2 py.PAUSE = 0.38
#       3 py.hotkey("alt", "tab")
#
# NameError: name 'py' is not defined
